# %%
from keras.layers import Embedding
from keras.datasets import imdb
from keras import preprocessing
from keras.models import Sequential
from keras.layers import Dense, Flatten, Embedding
from keras.callbacks import EarlyStopping
import os
import numpy as np

# %% [markdown]
# - Embedding Layer
#     - Accepts 2D Tensor input: <`num_samples`, `sequence_length`>
#     - `sequence_length` should be of fixed (same) length per batch of `samples`
#     - Initialized with random weights (internal dictionary of token weights), would get optimized through `backprop`

# %%
max_len = 20
max_features = 10000

(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=max_features)
# X_train[:5]

# %%
X_train = preprocessing.sequence.pad_sequences(X_train, maxlen=max_len)
X_test = preprocessing.sequence.pad_sequences(X_test, maxlen=max_len)

# %%
model = Sequential()

model.add(Embedding(max_features,8,input_length=max_len))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 20, 8)             80000
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 160)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 161
# =================================================================
# Total params: 80,161
# Trainable params: 80,161
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2, verbose=2)
# Out:
# Train on 20000 samples, validate on 5000 samples
# Epoch 1/20
#  - 3s - loss: 0.6651 - acc: 0.6228 - val_loss: 0.6016 - val_acc: 0.7052
# Epoch 2/20
#  - 1s - loss: 0.5009 - acc: 0.7820 - val_loss: 0.5094 - val_acc: 0.7440
# Epoch 3/20
#  - 1s - loss: 0.3895 - acc: 0.8388 - val_loss: 0.4942 - val_acc: 0.7498
# Epoch 4/20
#  - 1s - loss: 0.3155 - acc: 0.8804 - val_loss: 0.5008 - val_acc: 0.7482
# Epoch 5/20
#  - 1s - loss: 0.2558 - acc: 0.9113 - val_loss: 0.5174 - val_acc: 0.7482
# Epoch 6/20
#  - 1s - loss: 0.2065 - acc: 0.9347 - val_loss: 0.5428 - val_acc: 0.7430
# Epoch 7/20
#  - 1s - loss: 0.1653 - acc: 0.9557 - val_loss: 0.5696 - val_acc: 0.7392
# Epoch 8/20
#  - 1s - loss: 0.1317 - acc: 0.9689 - val_loss: 0.6048 - val_acc: 0.7372
# Epoch 9/20
#  - 2s - loss: 0.1045 - acc: 0.9784 - val_loss: 0.6395 - val_acc: 0.7350
# Epoch 10/20
#  - 1s - loss: 0.0827 - acc: 0.9866 - val_loss: 0.6774 - val_acc: 0.7306
# Epoch 11/20
#  - 1s - loss: 0.0647 - acc: 0.9908 - val_loss: 0.7194 - val_acc: 0.7318
# Epoch 12/20
#  - 1s - loss: 0.0505 - acc: 0.9941 - val_loss: 0.7611 - val_acc: 0.7266
# Epoch 13/20
#  - 1s - loss: 0.0392 - acc: 0.9968 - val_loss: 0.8058 - val_acc: 0.7256
# Epoch 14/20
#  - 1s - loss: 0.0302 - acc: 0.9978 - val_loss: 0.8515 - val_acc: 0.7236
# Epoch 15/20
#  - 1s - loss: 0.0232 - acc: 0.9988 - val_loss: 0.9028 - val_acc: 0.7258
# Epoch 16/20
#  - 1s - loss: 0.0177 - acc: 0.9994 - val_loss: 0.9474 - val_acc: 0.7216
# Epoch 17/20
#  - 1s - loss: 0.0134 - acc: 0.9997 - val_loss: 0.9975 - val_acc: 0.7200
# Epoch 18/20
#  - 1s - loss: 0.0102 - acc: 0.9998 - val_loss: 1.0495 - val_acc: 0.7210
# Epoch 19/20
#  - 1s - loss: 0.0078 - acc: 0.9999 - val_loss: 1.0956 - val_acc: 0.7198
# Epoch 20/20
#  - 1s - loss: 0.0059 - acc: 0.9999 - val_loss: 1.1468 - val_acc: 0.7194

# %% [markdown]
# - Above network `flatten`s the embedded input (3D Float Tensor) before feeding it to the `Dense` layer. This essentially doesn't contain any sequential information, which means no context about inter-word semantics is used for training the network
# - 1D Convnets or RNNs consider the sematinc information

# %% [markdown]
# ### Using pre-trained word embeddings

# %%
def load_imdb_raw_data(imdb_dir):
    
    texts = []; labels = []
    
    train_dir = os.path.join(imdb_dir, 'train')
    
    for label_type in ['pos', 'neg']:
        files_dir = os.path.join(train_dir, label_type)
        
        for fname in os.listdir(files_dir):
            if fname[-4:] == '.txt':
         
                f = open(os.path.join(files_dir,fname))
                texts.append(f.read())
                f.close()
                
                if label_type == 'neg':
                    labels.append(0)
                else:
                    labels.append(1)
    
    return (texts, labels)

# %%
# os.getcwd()
texts, labels = load_imdb_raw_data('../data/aclImdb/aclImdb/')
print("texts: {} labels: {}".format(len(texts), len(labels)))
# Out:
# texts: 25000 labels: 25000

# %%
max_len = 100

train_samples = 20000
validation_samples = 5000

tokenizer = preprocessing.text.Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(texts)

sequences = tokenizer.texts_to_sequences(texts)
word_index = tokenizer.word_index
data = preprocessing.sequence.pad_sequences(sequences, maxlen=max_len)
labels = np.asarray(labels)

print("data: {} labels: {}".format(data.shape, labels.shape))
# Out:
# data: (25000, 100) labels: (25000,)

# %%
# shuffle data indexes to shuffle pos/neg

indices = np.arange(data.shape[0])
np.random.shuffle(indices)

data = data[indices]
labels = labels[indices]

# %%
X_train = data[:train_samples]
y_train = labels[:train_samples]

X_test = data[train_samples:train_samples+validation_samples]
y_test = labels[train_samples:train_samples+validation_samples]

# %%
def create_glove_based_dict(path='../data/glove.6B/', file='glove.6B.100d.txt'):
    
    embedding_index = {}
    f = open(os.path.join(path,file))
    
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32') # word vector representation
        embedding_index[word] = coefs # assigned to the word/token at the index i of dictionary (i - when enumerated)
    
    f.close()
    print("Found {} word vectors".format(len(embedding_index)))

    return embedding_index

# %%
embedding_index = create_glove_based_dict()
# Out:
# Found 400000 word vectors

# %%
len(embedding_index['another']) # 100-d vector representation of each word in the vocabulary
# Out:
# 100

# %%
embedding_index['movie']
# Out:
# array([ 0.38251  ,  0.14821  ,  0.60601  , -0.51533  ,  0.43992  ,
#         0.061053 , -0.62716  , -0.025385 ,  0.1643   , -0.22101  ,
#         0.14423  , -0.37213  , -0.21683  , -0.08895  ,  0.097904 ,
#         0.6561   ,  0.64455  ,  0.47698  ,  0.83849  ,  1.6486   ,
#         0.88922  , -0.1181   , -0.012465 , -0.52082  ,  0.77854  ,
#         0.48723  , -0.014991 , -0.14127  , -0.34747  , -0.29595  ,
#         0.1028   ,  0.57191  , -0.045594 ,  0.026443 ,  0.53816  ,
#         0.32257  ,  0.40788  , -0.043599 , -0.146    , -0.48346  ,
#         0.32036  ,  0.55086  , -0.76259  ,  0.43269  ,  0.61753  ,
#        -0.36503  , -0.60599  , -0.79615  ,  0.3929   , -0.23668  ,
#        -0.34719  , -0.61201  ,  0.54747  ,  0.94812  ,  0.20941  ,
#        -2.7771   , -0.6022   ,  0.8495   ,  1.2549   ,  0.017893 ,
#        -0.041901 ,  2.1147   , -0.026618 , -0.28104  ,  0.68124  ,
#        -0.14165  ,  0.99249  ,  0.49879  , -0.67538  ,  0.6417   ,
#         0.42303  , -0.27913  ,  0.063403 ,  0.68909  , -0.36183  ,
#         0.053709 , -0.16806  ,  0.19422  , -0.47073  , -0.14803  ,
#        -0.58986  , -0.2797   ,  0.16792  ,  0.10568  , -1.7601   ,
#         0.0088254, -0.83326  , -0.5836   , -0.37079  , -0.56591  ,
#         0.20699  ,  0.071315 ,  0.055586 , -0.29757  , -0.072659 ,
#        -0.25596  ,  0.42688  ,  0.058921 ,  0.091112 ,  0.47283  ],
#       dtype=float32)

# %%
word_index # word_index created by the tokenizer based on the imdb texts
# Out:
# {'the': 1,
#  'and': 2,
#  'a': 3,
#  'of': 4,
#  'to': 5,
#  'is': 6,
#  'br': 7,
#  'in': 8,
#  'it': 9,
#  'i': 10,
#  'this': 11,
#  'that': 12,
#  'was': 13,
#  'as': 14,
#  'for': 15,
#  'with': 16,
#  'movie': 17,
#  'but': 18,
#  'film': 19,
#  'on': 20,
#  'not': 21,
#  'you': 22,
#  'are': 23,
#  'his': 24,
#  'have': 25,
#  'he': 26,
#  'be': 27,
#  'one': 28,
#  'all': 29,
#  'at': 30,
#  'by': 31,
#  'an': 32,
#  'they': 33,
#  'who': 34,
#  'so': 35,
#  'from': 36,
#  'like': 37,
#  'her': 38,
#  'or': 39,
#  'just': 40,
#  'about': 41,
#  "it's": 42,
#  'out': 43,
#  'has': 44,
#  'if': 45,
#  'some': 46,
#  'there': 47,
#  'what': 48,
#  'good': 49,
#  'more': 50,
#  'when': 51,
#  'very': 52,
#  'up': 53,
#  'no': 54,
#  'time': 55,
#  'she': 56,
#  'even': 57,
#  'my': 58,
#  'would': 59,
#  'which': 60,
#  'only': 61,
#  'story': 62,
#  'really': 63,
#  'see': 64,
#  'their': 65,
#  'had': 66,
#  'can': 67,
#  'were': 68,
#  'me': 69,
#  'well': 70,
#  'than': 71,
#  'we': 72,
#  'much': 73,
#  'been': 74,
#  'bad': 75,
#  'get': 76,
#  'will': 77,
#  'do': 78,
#  'also': 79,
#  'into': 80,
#  'people': 81,
#  'other': 82,
#  'first': 83,
#  'great': 84,
#  'because': 85,
#  'how': 86,
#  'him': 87,
#  'most': 88,
#  "don't": 89,
#  'made': 90,
#  'its': 91,
#  'then': 92,
#  'way': 93,
#  'make': 94,
#  'them': 95,
#  'too': 96,
#  'could': 97,
#  'any': 98,
#  'movies': 99,
#  'after': 100,
#  'think': 101,
#  'characters': 102,
#  'watch': 103,
#  'two': 104,
#  'films': 105,
#  'character': 106,
#  'seen': 107,
#  'many': 108,
#  'being': 109,
#  'life': 110,
#  'plot': 111,
#  'never': 112,
#  'acting': 113,
#  'little': 114,
#  'best': 115,
#  'love': 116,
#  'over': 117,
#  'where': 118,
#  'did': 119,
#  'show': 120,
#  'know': 121,
#  'off': 122,
#  'ever': 123,
#  'does': 124,
#  'better': 125,
#  'your': 126,
#  'end': 127,
#  'still': 128,
#  'man': 129,
#  'here': 130,
#  'these': 131,
#  'say': 132,
#  'scene': 133,
#  'while': 134,
#  'why': 135,
#  'scenes': 136,
#  'go': 137,
#  'such': 138,
#  'something': 139,
#  'through': 140,
#  'should': 141,
#  'back': 142,
#  "i'm": 143,
#  'real': 144,
#  'those': 145,
#  'watching': 146,
#  'now': 147,
#  'though': 148,
#  "doesn't": 149,
#  'years': 150,
#  'thing': 151,
#  'old': 152,
#  'actors': 153,
#  'work': 154,
#  '10': 155,
#  'before': 156,
#  'another': 157,
#  "didn't": 158,
#  'new': 159,
#  'funny': 160,
#  'nothing': 161,
#  'actually': 162,
#  'makes': 163,
#  'director': 164,
#  'look': 165,
#  'find': 166,
#  'going': 167,
#  'few': 168,
#  'same': 169,
#  'part': 170,
#  'again': 171,
#  'every': 172,
#  'lot': 173,
#  'cast': 174,
#  'us': 175,
#  'quite': 176,
#  'down': 177,
#  'want': 178,
#  'world': 179,
#  'things': 180,
#  'pretty': 181,
#  'young': 182,
#  'seems': 183,
#  'around': 184,
#  'got': 185,
#  'horror': 186,
#  'however': 187,
#  "can't": 188,
#  'fact': 189,
#  'take': 190,
#  'big': 191,
#  'enough': 192,
#  'long': 193,
#  'thought': 194,
#  "that's": 195,
#  'both': 196,
#  'between': 197,
#  'series': 198,
#  'give': 199,
#  'may': 200,
#  'original': 201,
#  'own': 202,
#  'action': 203,
#  "i've": 204,
#  'right': 205,
#  'without': 206,
#  'always': 207,
#  'times': 208,
#  'comedy': 209,
#  'point': 210,
#  'gets': 211,
#  'must': 212,
#  'come': 213,
#  'role': 214,
#  "isn't": 215,
#  'saw': 216,
#  'almost': 217,
#  'interesting': 218,
#  'least': 219,
#  'family': 220,
#  'done': 221,
#  "there's": 222,
#  'whole': 223,
#  'bit': 224,
#  'music': 225,
#  'script': 226,
#  'far': 227,
#  'making': 228,
#  'guy': 229,
#  'anything': 230,
#  'minutes': 231,
#  'feel': 232,
#  'last': 233,
#  'since': 234,
#  'might': 235,
#  'performance': 236,
#  "he's": 237,
#  '2': 238,
#  'probably': 239,
#  'kind': 240,
#  'am': 241,
#  'away': 242,
#  'yet': 243,
#  'rather': 244,
#  'tv': 245,
#  'worst': 246,
#  'girl': 247,
#  'day': 248,
#  'sure': 249,
#  'fun': 250,
#  'hard': 251,
#  'woman': 252,
#  'played': 253,
#  'each': 254,
#  'found': 255,
#  'anyone': 256,
#  'having': 257,
#  'although': 258,
#  'especially': 259,
#  'our': 260,
#  'course': 261,
#  'believe': 262,
#  'comes': 263,
#  'looking': 264,
#  'screen': 265,
#  'trying': 266,
#  'set': 267,
#  'goes': 268,
#  'looks': 269,
#  'place': 270,
#  'book': 271,
#  'different': 272,
#  'put': 273,
#  'ending': 274,
#  'money': 275,
#  'maybe': 276,
#  'once': 277,
#  'sense': 278,
#  'reason': 279,
#  'true': 280,
#  'actor': 281,
#  'everything': 282,
#  "wasn't": 283,
#  'shows': 284,
#  'dvd': 285,
#  'three': 286,
#  'worth': 287,
#  'year': 288,
#  'job': 289,
#  'main': 290,
#  'someone': 291,
#  'together': 292,
#  'watched': 293,
#  'play': 294,
#  'plays': 295,
#  'american': 296,
#  '1': 297,
#  'said': 298,
#  'effects': 299,
#  'later': 300,
#  'takes': 301,
#  'instead': 302,
#  'seem': 303,
#  'beautiful': 304,
#  'john': 305,
#  'himself': 306,
#  'version': 307,
#  'audience': 308,
#  'high': 309,
#  'house': 310,
#  'night': 311,
#  'during': 312,
#  'everyone': 313,
#  'left': 314,
#  'special': 315,
#  'seeing': 316,
#  'half': 317,
#  'excellent': 318,
#  'wife': 319,
#  'star': 320,
#  'shot': 321,
#  'war': 322,
#  'idea': 323,
#  'nice': 324,
#  'black': 325,
#  'less': 326,
#  'mind': 327,
#  'simply': 328,
#  'read': 329,
#  'second': 330,
#  'else': 331,
#  "you're": 332,
#  'father': 333,
#  'fan': 334,
#  'help': 335,
#  'poor': 336,
#  'completely': 337,
#  'death': 338,
#  '3': 339,
#  'used': 340,
#  'home': 341,
#  'either': 342,
#  'short': 343,
#  'line': 344,
#  'given': 345,
#  'men': 346,
#  'top': 347,
#  'dead': 348,
#  'budget': 349,
#  'try': 350,
#  'performances': 351,
#  'wrong': 352,
#  'classic': 353,
#  'enjoy': 354,
#  'boring': 355,
#  'need': 356,
#  'rest': 357,
#  'use': 358,
#  'hollywood': 359,
#  'kids': 360,
#  'low': 361,
#  'production': 362,
#  'until': 363,
#  'along': 364,
#  'full': 365,
#  'friends': 366,
#  'camera': 367,
#  'truly': 368,
#  'women': 369,
#  'awful': 370,
#  'video': 371,
#  'next': 372,
#  'tell': 373,
#  'remember': 374,
#  'couple': 375,
#  'stupid': 376,
#  'start': 377,
#  'perhaps': 378,
#  'stars': 379,
#  'sex': 380,
#  'mean': 381,
#  'came': 382,
#  'recommend': 383,
#  'let': 384,
#  'moments': 385,
#  'wonderful': 386,
#  'episode': 387,
#  'understand': 388,
#  'small': 389,
#  'face': 390,
#  'terrible': 391,
#  'school': 392,
#  'playing': 393,
#  'getting': 394,
#  'written': 395,
#  'often': 396,
#  'doing': 397,
#  'keep': 398,
#  'early': 399,
#  'perfect': 400,
#  'name': 401,
#  'style': 402,
#  'human': 403,
#  'definitely': 404,
#  'gives': 405,
#  'others': 406,
#  'itself': 407,
#  'lines': 408,
#  'live': 409,
#  'become': 410,
#  'dialogue': 411,
#  'person': 412,
#  'lost': 413,
#  'finally': 414,
#  'piece': 415,
#  'head': 416,
#  'case': 417,
#  'felt': 418,
#  'yes': 419,
#  'liked': 420,
#  'supposed': 421,
#  'title': 422,
#  "couldn't": 423,
#  'absolutely': 424,
#  'white': 425,
#  'against': 426,
#  'boy': 427,
#  'picture': 428,
#  'sort': 429,
#  'worse': 430,
#  'certainly': 431,
#  'went': 432,
#  'entire': 433,
#  'cinema': 434,
#  'waste': 435,
#  'problem': 436,
#  'hope': 437,
#  'entertaining': 438,
#  "she's": 439,
#  'mr': 440,
#  'overall': 441,
#  'evil': 442,
#  'called': 443,
#  'loved': 444,
#  'based': 445,
#  'oh': 446,
#  'several': 447,
#  'fans': 448,
#  'mother': 449,
#  'drama': 450,
#  'beginning': 451,
#  'killer': 452,
#  'lives': 453,
#  '5': 454,
#  'direction': 455,
#  'care': 456,
#  'already': 457,
#  'becomes': 458,
#  'example': 459,
#  'laugh': 460,
#  'friend': 461,
#  'dark': 462,
#  'under': 463,
#  'despite': 464,
#  'seemed': 465,
#  'throughout': 466,
#  '4': 467,
#  'turn': 468,
#  'unfortunately': 469,
#  'wanted': 470,
#  "i'd": 471,
#  '\x96': 472,
#  'children': 473,
#  'final': 474,
#  'fine': 475,
#  'history': 476,
#  'amazing': 477,
#  'sound': 478,
#  'guess': 479,
#  'heart': 480,
#  'totally': 481,
#  'humor': 482,
#  'lead': 483,
#  'writing': 484,
#  'michael': 485,
#  'quality': 486,
#  "you'll": 487,
#  'close': 488,
#  'son': 489,
#  'wants': 490,
#  'guys': 491,
#  'works': 492,
#  'behind': 493,
#  'tries': 494,
#  'art': 495,
#  'side': 496,
#  'game': 497,
#  'past': 498,
#  'able': 499,
#  'b': 500,
#  'days': 501,
#  'turns': 502,
#  "they're": 503,
#  'child': 504,
#  'hand': 505,
#  'enjoyed': 506,
#  'flick': 507,
#  'act': 508,
#  'genre': 509,
#  'town': 510,
#  'favorite': 511,
#  'soon': 512,
#  'kill': 513,
#  'starts': 514,
#  'sometimes': 515,
#  'gave': 516,
#  'car': 517,
#  'run': 518,
#  'late': 519,
#  'eyes': 520,
#  'actress': 521,
#  'etc': 522,
#  'directed': 523,
#  'horrible': 524,
#  "won't": 525,
#  'viewer': 526,
#  'brilliant': 527,
#  'parts': 528,
#  'themselves': 529,
#  'self': 530,
#  'hour': 531,
#  'expect': 532,
#  'thinking': 533,
#  'stories': 534,
#  'stuff': 535,
#  'girls': 536,
#  'obviously': 537,
#  'blood': 538,
#  'decent': 539,
#  'city': 540,
#  'voice': 541,
#  'highly': 542,
#  'myself': 543,
#  'feeling': 544,
#  'fight': 545,
#  'except': 546,
#  'slow': 547,
#  'matter': 548,
#  'type': 549,
#  'anyway': 550,
#  'kid': 551,
#  'roles': 552,
#  'heard': 553,
#  'killed': 554,
#  'age': 555,
#  'god': 556,
#  'says': 557,
#  'moment': 558,
#  'took': 559,
#  'leave': 560,
#  'writer': 561,
#  'strong': 562,
#  'cannot': 563,
#  'violence': 564,
#  'police': 565,
#  'hit': 566,
#  'happens': 567,
#  'stop': 568,
#  'particularly': 569,
#  'known': 570,
#  'happened': 571,
#  'involved': 572,
#  'extremely': 573,
#  'obvious': 574,
#  'daughter': 575,
#  'chance': 576,
#  'told': 577,
#  'living': 578,
#  'coming': 579,
#  'lack': 580,
#  'alone': 581,
#  'experience': 582,
#  'including': 583,
#  "wouldn't": 584,
#  'murder': 585,
#  'attempt': 586,
#  's': 587,
#  'james': 588,
#  'please': 589,
#  'happen': 590,
#  'wonder': 591,
#  'crap': 592,
#  "film's": 593,
#  'brother': 594,
#  'ago': 595,
#  'gore': 596,
#  'none': 597,
#  'complete': 598,
#  'interest': 599,
#  'score': 600,
#  'group': 601,
#  'cut': 602,
#  'simple': 603,
#  'save': 604,
#  'looked': 605,
#  'hell': 606,
#  'ok': 607,
#  'career': 608,
#  'number': 609,
#  'song': 610,
#  'possible': 611,
#  'seriously': 612,
#  'annoying': 613,
#  'exactly': 614,
#  'shown': 615,
#  'sad': 616,
#  'running': 617,
#  'serious': 618,
#  'musical': 619,
#  'yourself': 620,
#  'taken': 621,
#  'whose': 622,
#  'released': 623,
#  'david': 624,
#  'cinematography': 625,
#  'scary': 626,
#  'ends': 627,
#  'english': 628,
#  'usually': 629,
#  'hero': 630,
#  'hours': 631,
#  'reality': 632,
#  'opening': 633,
#  "i'll": 634,
#  'today': 635,
#  'jokes': 636,
#  'across': 637,
#  'light': 638,
#  'hilarious': 639,
#  'somewhat': 640,
#  'usual': 641,
#  'body': 642,
#  'ridiculous': 643,
#  'started': 644,
#  'cool': 645,
#  'level': 646,
#  'relationship': 647,
#  'view': 648,
#  'change': 649,
#  'opinion': 650,
#  'happy': 651,
#  'middle': 652,
#  'taking': 653,
#  'wish': 654,
#  'husband': 655,
#  'finds': 656,
#  'saying': 657,
#  'order': 658,
#  'ones': 659,
#  'talking': 660,
#  'shots': 661,
#  'documentary': 662,
#  'huge': 663,
#  'novel': 664,
#  'female': 665,
#  'mostly': 666,
#  'power': 667,
#  'robert': 668,
#  'episodes': 669,
#  'room': 670,
#  'important': 671,
#  'rating': 672,
#  'talent': 673,
#  'five': 674,
#  'major': 675,
#  'turned': 676,
#  'strange': 677,
#  'word': 678,
#  'modern': 679,
#  'call': 680,
#  'apparently': 681,
#  'disappointed': 682,
#  'single': 683,
#  'events': 684,
#  'four': 685,
#  'due': 686,
#  'songs': 687,
#  'attention': 688,
#  'basically': 689,
#  '7': 690,
#  'knows': 691,
#  'clearly': 692,
#  'knew': 693,
#  'supporting': 694,
#  'british': 695,
#  'non': 696,
#  'television': 697,
#  'comic': 698,
#  'earth': 699,
#  'fast': 700,
#  'country': 701,
#  'class': 702,
#  'cheap': 703,
#  'future': 704,
#  '8': 705,
#  'silly': 706,
#  'thriller': 707,
#  'king': 708,
#  'problems': 709,
#  "aren't": 710,
#  'easily': 711,
#  'words': 712,
#  'tells': 713,
#  'miss': 714,
#  'jack': 715,
#  'local': 716,
#  'sequence': 717,
#  'bring': 718,
#  'entertainment': 719,
#  'paul': 720,
#  'beyond': 721,
#  'upon': 722,
#  'whether': 723,
#  'moving': 724,
#  'predictable': 725,
#  'straight': 726,
#  'sets': 727,
#  'similar': 728,
#  'romantic': 729,
#  'review': 730,
#  'falls': 731,
#  'oscar': 732,
#  'mystery': 733,
#  'enjoyable': 734,
#  'talk': 735,
#  'needs': 736,
#  'rock': 737,
#  'appears': 738,
#  'george': 739,
#  'giving': 740,
#  'eye': 741,
#  'within': 742,
#  'richard': 743,
#  'ten': 744,
#  'animation': 745,
#  'message': 746,
#  'near': 747,
#  'theater': 748,
#  'above': 749,
#  'dull': 750,
#  'nearly': 751,
#  'sequel': 752,
#  'theme': 753,
#  'points': 754,
#  "'": 755,
#  'stand': 756,
#  'mention': 757,
#  'lady': 758,
#  'bunch': 759,
#  'add': 760,
#  'feels': 761,
#  'herself': 762,
#  'release': 763,
#  'red': 764,
#  'team': 765,
#  'storyline': 766,
#  'surprised': 767,
#  'ways': 768,
#  'using': 769,
#  'named': 770,
#  "haven't": 771,
#  'easy': 772,
#  'lots': 773,
#  'fantastic': 774,
#  'begins': 775,
#  'actual': 776,
#  'working': 777,
#  'effort': 778,
#  'york': 779,
#  'french': 780,
#  'die': 781,
#  'hate': 782,
#  'tale': 783,
#  'minute': 784,
#  '9': 785,
#  'stay': 786,
#  'clear': 787,
#  'feature': 788,
#  'elements': 789,
#  'among': 790,
#  'follow': 791,
#  'comments': 792,
#  're': 793,
#  'viewers': 794,
#  'avoid': 795,
#  'sister': 796,
#  'showing': 797,
#  'typical': 798,
#  'editing': 799,
#  'tried': 800,
#  'famous': 801,
#  "what's": 802,
#  'sorry': 803,
#  'check': 804,
#  'fall': 805,
#  'dialog': 806,
#  'period': 807,
#  'form': 808,
#  'season': 809,
#  'certain': 810,
#  'filmed': 811,
#  'soundtrack': 812,
#  'weak': 813,
#  'means': 814,
#  'material': 815,
#  'buy': 816,
#  'realistic': 817,
#  'somehow': 818,
#  'crime': 819,
#  'figure': 820,
#  'doubt': 821,
#  'gone': 822,
#  'peter': 823,
#  'tom': 824,
#  'viewing': 825,
#  'kept': 826,
#  't': 827,
#  'general': 828,
#  'leads': 829,
#  'greatest': 830,
#  'space': 831,
#  'lame': 832,
#  'dance': 833,
#  'suspense': 834,
#  'brought': 835,
#  'imagine': 836,
#  'third': 837,
#  'atmosphere': 838,
#  'hear': 839,
#  'particular': 840,
#  'sequences': 841,
#  'whatever': 842,
#  'parents': 843,
#  'move': 844,
#  'lee': 845,
#  'indeed': 846,
#  'eventually': 847,
#  'learn': 848,
#  'rent': 849,
#  'de': 850,
#  'note': 851,
#  'wait': 852,
#  'reviews': 853,
#  'deal': 854,
#  'average': 855,
#  'forget': 856,
#  'japanese': 857,
#  'sexual': 858,
#  'poorly': 859,
#  'okay': 860,
#  'premise': 861,
#  'surprise': 862,
#  'zombie': 863,
#  'stage': 864,
#  'believable': 865,
#  'possibly': 866,
#  'sit': 867,
#  "who's": 868,
#  'decided': 869,
#  'expected': 870,
#  "you've": 871,
#  'subject': 872,
#  'nature': 873,
#  'became': 874,
#  'difficult': 875,
#  'free': 876,
#  'screenplay': 877,
#  'killing': 878,
#  'truth': 879,
#  'romance': 880,
#  'dr': 881,
#  'nor': 882,
#  'reading': 883,
#  'question': 884,
#  'needed': 885,
#  'leaves': 886,
#  'street': 887,
#  '20': 888,
#  'meets': 889,
#  'hot': 890,
#  'unless': 891,
#  'begin': 892,
#  'baby': 893,
#  'otherwise': 894,
#  'imdb': 895,
#  'superb': 896,
#  'credits': 897,
#  'write': 898,
#  'shame': 899,
#  "let's": 900,
#  'dramatic': 901,
#  'situation': 902,
#  'memorable': 903,
#  'directors': 904,
#  'earlier': 905,
#  'meet': 906,
#  'dog': 907,
#  'open': 908,
#  'badly': 909,
#  'disney': 910,
#  'male': 911,
#  'weird': 912,
#  'joe': 913,
#  'acted': 914,
#  'forced': 915,
#  'laughs': 916,
#  'sci': 917,
#  'emotional': 918,
#  'older': 919,
#  'realize': 920,
#  'dream': 921,
#  'fi': 922,
#  'society': 923,
#  'interested': 924,
#  'writers': 925,
#  'forward': 926,
#  'comment': 927,
#  'footage': 928,
#  'crazy': 929,
#  'deep': 930,
#  'whom': 931,
#  'beauty': 932,
#  'america': 933,
#  'sounds': 934,
#  'plus': 935,
#  'fantasy': 936,
#  'directing': 937,
#  'keeps': 938,
#  'ask': 939,
#  'development': 940,
#  'features': 941,
#  'quickly': 942,
#  'air': 943,
#  'creepy': 944,
#  'mess': 945,
#  'perfectly': 946,
#  'towards': 947,
#  'mark': 948,
#  'worked': 949,
#  'box': 950,
#  'unique': 951,
#  'cheesy': 952,
#  'hands': 953,
#  'setting': 954,
#  'plenty': 955,
#  'brings': 956,
#  'previous': 957,
#  'result': 958,
#  'e': 959,
#  'total': 960,
#  'effect': 961,
#  'personal': 962,
#  'incredibly': 963,
#  'fire': 964,
#  'rate': 965,
#  'monster': 966,
#  'business': 967,
#  'leading': 968,
#  'casting': 969,
#  'apart': 970,
#  'admit': 971,
#  'powerful': 972,
#  'background': 973,
#  'joke': 974,
#  'appear': 975,
#  'telling': 976,
#  'meant': 977,
#  'girlfriend': 978,
#  'present': 979,
#  'hardly': 980,
#  'christmas': 981,
#  'battle': 982,
#  'potential': 983,
#  'create': 984,
#  'break': 985,
#  'bill': 986,
#  'pay': 987,
#  'masterpiece': 988,
#  'return': 989,
#  'dumb': 990,
#  'political': 991,
#  'gay': 992,
#  'fighting': 993,
#  'fails': 994,
#  'various': 995,
#  'era': 996,
#  'portrayed': 997,
#  'secret': 998,
#  'co': 999,
#  'cop': 1000,
#  ...}

# %%
embedding_dim = 100

embedding_matrix = np.zeros((max_features, embedding_dim))

for word, idx in word_index.items():
    
    if idx < max_features:
        embedding_vector = embedding_index.get(word)
        if embedding_vector is not None:
            embedding_matrix[idx] = embedding_vector

# %%
model = Sequential()
model.add(Embedding(max_features, embedding_dim, input_length=max_len))
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 100, 100)          1000000
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 10000)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                320032
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 1,320,065
# Trainable params: 1,320,065
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.layers[0].set_weights([embedding_matrix])
model.layers[0].trainable = False

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 100, 100)          1000000
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 10000)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                320032
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 1,320,065
# Trainable params: 320,065
# Non-trainable params: 1,000,000
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['acc'])
history = model.fit(X_train, y_train, epochs=20,batch_size=32,validation_data=(X_test, y_test))
model.save_weights('pre_trained_glove_model.h5')
# Out:
# Train on 20000 samples, validate on 5000 samples
# Epoch 1/20
# 20000/20000 [==============================] - 8s 403us/step - loss: 0.6104 - acc: 0.6712 - val_loss: 0.5902 - val_acc: 0.6884
# Epoch 2/20
# 20000/20000 [==============================] - 8s 386us/step - loss: 0.4875 - acc: 0.7653 - val_loss: 0.5640 - val_acc: 0.7142
# Epoch 3/20
# 20000/20000 [==============================] - 9s 427us/step - loss: 0.4194 - acc: 0.8050 - val_loss: 0.5705 - val_acc: 0.7206
# Epoch 4/20
# 20000/20000 [==============================] - 7s 369us/step - loss: 0.3782 - acc: 0.8273 - val_loss: 0.5838 - val_acc: 0.7170
# Epoch 5/20
# 20000/20000 [==============================] - 8s 400us/step - loss: 0.3475 - acc: 0.8423 - val_loss: 0.6556 - val_acc: 0.7150
# Epoch 6/20
# 20000/20000 [==============================] - 8s 379us/step - loss: 0.2849 - acc: 0.8760 - val_loss: 0.6614 - val_acc: 0.7116
# Epoch 7/20
# 20000/20000 [==============================] - 7s 358us/step - loss: 0.2448 - acc: 0.8958 - val_loss: 0.7708 - val_acc: 0.7100
# Epoch 8/20
# 20000/20000 [==============================] - 7s 368us/step - loss: 0.1981 - acc: 0.9186 - val_loss: 0.8922 - val_acc: 0.7080
# Epoch 9/20
# 20000/20000 [==============================] - 8s 379us/step - loss: 0.1514 - acc: 0.9411 - val_loss: 1.0137 - val_acc: 0.7086
# Epoch 10/20
# 20000/20000 [==============================] - 7s 350us/step - loss: 0.1176 - acc: 0.9550 - val_loss: 1.0909 - val_acc: 0.7026
# Epoch 11/20
# 20000/20000 [==============================] - 7s 357us/step - loss: 0.0835 - acc: 0.9697 - val_loss: 1.2219 - val_acc: 0.6942
# Epoch 12/20
# 20000/20000 [==============================] - 7s 355us/step - loss: 0.0645 - acc: 0.9788 - val_loss: 1.3375 - val_acc: 0.6890
# Epoch 13/20
# 20000/20000 [==============================] - 7s 352us/step - loss: 0.0635 - acc: 0.9772 - val_loss: 1.3922 - val_acc: 0.6960
# Epoch 14/20
# 20000/20000 [==============================] - 8s 378us/step - loss: 0.0578 - acc: 0.9777 - val_loss: 1.4537 - val_acc: 0.6960
# Epoch 15/20
# 20000/20000 [==============================] - 7s 353us/step - loss: 0.0440 - acc: 0.9833 - val_loss: 1.5439 - val_acc: 0.6890
# Epoch 16/20
# 20000/20000 [==============================] - 8s 379us/step - loss: 0.0468 - acc: 0.9826 - val_loss: 1.9324 - val_acc: 0.7018
# Epoch 17/20
# 20000/20000 [==============================] - 7s 351us/step - loss: 0.0423 - acc: 0.9835 - val_loss: 1.8083 - val_acc: 0.6988
# Epoch 18/20
# 20000/20000 [==============================] - 7s 371us/step - loss: 0.0400 - acc: 0.9844 - val_loss: 1.9970 - val_acc: 0.6770
# Epoch 19/20
# 20000/20000 [==============================] - 8s 400us/step - loss: 0.0338 - acc: 0.9855 - val_loss: 1.9119 - val_acc: 0.6964
# Epoch 20/20
# 20000/20000 [==============================] - 7s 371us/step - loss: 0.0191 - acc: 0.9922 - val_loss: 2.0698 - val_acc: 0.7016
